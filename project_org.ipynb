# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %%
df1=pd.read_csv('datafile1.csv',skiprows=20)
df2=pd.read_csv('datafile2.csv',skiprows=17)

# %%
df1.head()
# Out:
#         LAT       LON  YEAR  MO  DY  PRECTOT  QV2M   RH2M     PS  T2M_RANGE  \
# 0  27.66671  85.35001  2013   1   1     0.00  3.61  43.19  84.00      10.74
# 1  27.66671  85.35001  2013   1   2     0.06  2.88  33.65  84.07      11.65
# 2  27.66671  85.35001  2013   1   3     0.00  2.99  38.91  84.08      10.75
# 3  27.66671  85.35001  2013   1   4     0.00  2.77  36.93  84.09      11.64
# 4  27.66671  85.35001  2013   1   5     0.00  2.37  33.48  83.93      11.96
#
#      TS  T2MDEW  T2MWET  T2M_MAX  T2M_MIN   T2M
# 0  5.30   -3.79   -3.60    15.23     4.49  8.72
# 1  5.43   -6.77   -6.42    16.82     5.17  9.08
# 2  4.72   -6.33   -6.08    14.58     3.84  7.50
# 3  3.93   -7.48   -7.12    14.69     3.06  7.12
# 4  3.07   -9.67   -9.06    13.81     1.85  6.29

# %%
df2.head()
# Out:
#         LAT       LON  YEAR  MO  DY  WS50M_RANGE  WS10M_RANGE  WS50M_MIN  \
# 0  27.66671  85.35001  2013   1   1         2.36         3.35       0.91
# 1  27.66671  85.35001  2013   1   2         1.91         2.64       0.90
# 2  27.66671  85.35001  2013   1   3         2.92         3.33       1.28
# 3  27.66671  85.35001  2013   1   4         2.57         3.26       1.89
# 4  27.66671  85.35001  2013   1   5         1.94         2.69       1.57
#
#    WS10M_MIN  WS50M_MAX  WS10M_MAX  WS50M  WS10M
# 0       0.67       3.27       4.02   1.64   1.61
# 1       0.64       2.82       3.29   1.57   1.47
# 2       1.08       4.20       4.41   2.27   1.99
# 3       1.26       4.46       4.51   2.91   2.38
# 4       1.05       3.51       3.74   2.50   2.08

# %%
#merging two csvs
df=df=pd.merge(df1,df2,how='left',on=('LAT','LON','YEAR','MO','DY'))
df.head()
# Out:
#         LAT       LON  YEAR  MO  DY  PRECTOT  QV2M   RH2M     PS  T2M_RANGE  \
# 0  27.66671  85.35001  2013   1   1     0.00  3.61  43.19  84.00      10.74
# 1  27.66671  85.35001  2013   1   2     0.06  2.88  33.65  84.07      11.65
# 2  27.66671  85.35001  2013   1   3     0.00  2.99  38.91  84.08      10.75
# 3  27.66671  85.35001  2013   1   4     0.00  2.77  36.93  84.09      11.64
# 4  27.66671  85.35001  2013   1   5     0.00  2.37  33.48  83.93      11.96
#
#    ...  T2M_MIN   T2M  WS50M_RANGE  WS10M_RANGE  WS50M_MIN  WS10M_MIN  \
# 0  ...     4.49  8.72         2.36         3.35       0.91       0.67
# 1  ...     5.17  9.08         1.91         2.64       0.90       0.64
# 2  ...     3.84  7.50         2.92         3.33       1.28       1.08
# 3  ...     3.06  7.12         2.57         3.26       1.89       1.26
# 4  ...     1.85  6.29         1.94         2.69       1.57       1.05
#
#    WS50M_MAX  WS10M_MAX  WS50M  WS10M
# 0       3.27       4.02   1.64   1.61
# 1       2.82       3.29   1.57   1.47
# 2       4.20       4.41   2.27   1.99
# 3       4.46       4.51   2.91   2.38
# 4       3.51       3.74   2.50   2.08
#
# [5 rows x 24 columns]

# %%
df['MO']=df.MO.astype(str)
df['YEAR']=df.YEAR.astype(str)
df['DY']=df.DY.astype(str)

df['date']=df['YEAR'].str.cat(df['MO'],sep='/')
df['Date']=df['date'].str.cat(df['DY'],sep='/')
df.head()
# Out:
#         LAT       LON  YEAR MO DY  PRECTOT  QV2M   RH2M     PS  T2M_RANGE  \
# 0  27.66671  85.35001  2013  1  1     0.00  3.61  43.19  84.00      10.74
# 1  27.66671  85.35001  2013  1  2     0.06  2.88  33.65  84.07      11.65
# 2  27.66671  85.35001  2013  1  3     0.00  2.99  38.91  84.08      10.75
# 3  27.66671  85.35001  2013  1  4     0.00  2.77  36.93  84.09      11.64
# 4  27.66671  85.35001  2013  1  5     0.00  2.37  33.48  83.93      11.96
#
#    ...  WS50M_RANGE  WS10M_RANGE  WS50M_MIN  WS10M_MIN  WS50M_MAX  WS10M_MAX  \
# 0  ...         2.36         3.35       0.91       0.67       3.27       4.02
# 1  ...         1.91         2.64       0.90       0.64       2.82       3.29
# 2  ...         2.92         3.33       1.28       1.08       4.20       4.41
# 3  ...         2.57         3.26       1.89       1.26       4.46       4.51
# 4  ...         1.94         2.69       1.57       1.05       3.51       3.74
#
#    WS50M  WS10M    date      Date
# 0   1.64   1.61  2013/1  2013/1/1
# 1   1.57   1.47  2013/1  2013/1/2
# 2   2.27   1.99  2013/1  2013/1/3
# 3   2.91   2.38  2013/1  2013/1/4
# 4   2.50   2.08  2013/1  2013/1/5
#
# [5 rows x 26 columns]

# %%
#removing lat and lon columns
df.drop(columns=['YEAR','MO','DY','LAT','LON','QV2M','date','WS50M_RANGE', 'WS50M_MIN','WS50M_MAX', 'WS50M','T2MDEW', 'T2MWET',
       'WS10M_MIN', 'WS10M_MAX','WS10M','TS','T2M','T2M_RANGE'],axis=1,inplace=True)
df.head()
# Out:
#    PRECTOT   RH2M     PS  T2M_MAX  T2M_MIN  WS10M_RANGE      Date
# 0     0.00  43.19  84.00    15.23     4.49         3.35  2013/1/1
# 1     0.06  33.65  84.07    16.82     5.17         2.64  2013/1/2
# 2     0.00  38.91  84.08    14.58     3.84         3.33  2013/1/3
# 3     0.00  36.93  84.09    14.69     3.06         3.26  2013/1/4
# 4     0.00  33.48  83.93    13.81     1.85         2.69  2013/1/5

# %%
df.set_index(['Date'],inplace=True)
df.head()
# Out:
#           PRECTOT   RH2M     PS  T2M_MAX  T2M_MIN  WS10M_RANGE
# Date
# 2013/1/1     0.00  43.19  84.00    15.23     4.49         3.35
# 2013/1/2     0.06  33.65  84.07    16.82     5.17         2.64
# 2013/1/3     0.00  38.91  84.08    14.58     3.84         3.33
# 2013/1/4     0.00  36.93  84.09    14.69     3.06         3.26
# 2013/1/5     0.00  33.48  83.93    13.81     1.85         2.69

# %%
df.dtypes
# Out:
# PRECTOT        float64
# RH2M           float64
# PS             float64
# T2M_MAX        float64
# T2M_MIN        float64
# WS10M_RANGE    float64
# dtype: object

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2556 entries, 2013/1/1 to 2019/12/31
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PRECTOT      2556 non-null   float64
#  1   RH2M         2556 non-null   float64
#  2   PS           2556 non-null   float64
#  3   T2M_MAX      2556 non-null   float64
#  4   T2M_MIN      2556 non-null   float64
#  5   WS10M_RANGE  2556 non-null   float64
# dtypes: float64(6)
# memory usage: 139.8+ KB

# %%
df.tail()
# Out:
#             PRECTOT   RH2M     PS  T2M_MAX  T2M_MIN  WS10M_RANGE
# Date
# 2019/12/27      0.0  54.14  84.01    11.10     0.29         2.62
# 2019/12/28      0.0  50.06  84.27    12.44    -2.01         2.69
# 2019/12/29      0.0  44.74  84.33    13.56     3.12         2.42
# 2019/12/30      0.0  44.56  84.39    13.74     3.24         2.63
# 2019/12/31      0.0  40.99  84.51    13.63     4.76         2.74

# %% [markdown]
# # New Section

# %%
fig,ax=plt.subplots(figsize=(25,25))
for i in range(len(df.columns)):
  plt.subplot(len(df.columns),1,i+1)
  name=df.columns[i]
  plt.plot(df[name])
  plt.title(name,y=0,loc='right')
  plt.yticks([])
plt.show()
fig.tight_layout()

# %%
plt.figure(figsize=(30,5))
df['PRECTOT'].plot()

# %%
df.columns

# %%
df.describe()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scalar=MinMaxScaler()

# %%
#scale the data
data_train=df.loc[:'2017/12/31',:][[  'PRECTOT', 'RH2M', 'PS', 'T2M_MAX', 'T2M_MIN', 'WS10M_RANGE']]
data_test=df.loc['2018/1/1':'2019/12/31',:][[  'PRECTOT', 'RH2M', 'PS',  'T2M_MAX', 'T2M_MIN','WS10M_RANGE']]



data_train_scaled=scalar.fit_transform(data_train)
data_test_scaled=scalar.transform(data_test)

# %%
#create training and testing dataset
#splitting data into X and Y for training  
x_train,y_train=[],[]
for i in range(1,len(data_train_scaled)):
  x_train.append(data_train_scaled[i-1])
  y_train.append(data_train_scaled[i])


#splitting data into X and Y for testing
x_test=[]
y_test=[]
for i in range(1,len(data_test_scaled)):
  x_test.append(data_test_scaled[i-1])
  y_test.append(data_test_scaled[i])

# %%
pd.DataFrame(y_train)
# Out:
#              0         1         2         3         4         5
# 0     0.001041  0.246827  0.629213  0.323835  0.313590  0.187959
# 1     0.000000  0.308068  0.634831  0.222524  0.252525  0.289280
# 2     0.000000  0.285016  0.640449  0.227499  0.216713  0.279001
# 3     0.000000  0.244848  0.550562  0.187698  0.161157  0.195301
# 4     0.000000  0.182792  0.589888  0.137494  0.101010  0.165932
# ...        ...       ...       ...       ...       ...       ...
# 1820  0.000000  0.283269  0.780899  0.408412  0.346648  0.214391
# 1821  0.000000  0.230411  0.786517  0.400724  0.472452  0.199706
# 1822  0.000000  0.228781  0.825843  0.417006  0.443985  0.207048
# 1823  0.000000  0.244732  0.814607  0.398915  0.435721  0.350954
# 1824  0.000000  0.284666  0.724719  0.347354  0.388430  0.187959
#
# [1825 rows x 6 columns]

# %%
x_train,y_train=np.array(x_train),np.array(y_train)
x_train.shape,y_train.shape
# Out:
# ((1825, 6), (1825, 6))

# %%
x_test=np.array(x_test)
y_test=np.array(y_test)
x_test.shape
# Out:
# (729, 6)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import Adam
from keras.models import load_model
from keras.layers import
# 122/122 [==============================] - 0s 752us/step - loss: 0.0054 - accuracy: 0.8279 - val_loss: 0.0052 - val_accuracy: 0.8134
# Epoch 141/150
# 122/122 [==============================] - 0s 768us/step - loss: 0.0054 - accuracy: 0.8263 - val_loss: 0.0052 - val_accuracy: 0.8107
# Epoch 142/150
# 122/122 [==============================] - 0s 801us/step - loss: 0.0055 - accuracy: 0.8241 - val_loss: 0.0052 - val_accuracy: 0.8176
# Epoch 143/150
# 122/122 [==============================] - 0s 785us/step - loss: 0.0055 - accuracy: 0.8268 - val_loss: 0.0053 - val_accuracy: 0.8107
# Epoch 144/150
# 122/122 [==============================] - 0s 817us/step - loss: 0.0056 - accuracy: 0.8181 - val_loss: 0.0058 - val_accuracy: 0.8052
# Epoch 145/150
# 122/122 [==============================] - 0s 777us/step - loss: 0.0061 - accuracy: 0.8241 - val_loss: 0.0059 - val_accuracy: 0.8093
# Epoch 146/150
# 122/122 [==============================] - 0s 761us/step - loss: 0.0060 - accuracy: 0.8197 - val_loss: 0.0059 - val_accuracy: 0.8080
# Epoch 147/150
# 122/122 [==============================] - 0s 801us/step - loss: 0.0059 - accuracy: 0.8214 - val_loss: 0.0052 - val_accuracy: 0.8134
# Epoch 148/150
# 122/122 [==============================] - 0s 744us/step - loss: 0.0055 - accuracy: 0.8285 - val_loss: 0.0053 - val_accuracy: 0.8066
# Epoch 149/150
# 122/122 [==============================] - 0s 760us/step - loss: 0.0055 - accuracy: 0.8290 - val_loss: 0.0051 - val_accuracy: 0.8080
# Epoch 150/150
# 122/122 [==============================] - 0s 736us/step - loss: 0.0054 - accuracy: 0.8268 - val_loss: 0.0052 - val_accuracy: 0.8080

# %%
# save model and architecture to single file
model.save("model222.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
model = load_model('model222.h5')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 20)                140
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 126
# =================================================================
# Total params: 686
# Trainable params: 686
# Non-trainable params: 0
# _________________________________________________________________

# %%
ans=model.predict(x_test,batch_size=15)
ans=scalar.inverse_transform(ans)
actual_value=scalar.inverse_transform(y_test)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-9226d5378aca> in <module>
# ----> 1 plt.plot(history.history['accuracy'])
#       2 plt.plot(history.history['val_accuracy'])
#       3 plt.title('Training and Validation accuracy')
#       4 plt.xlabel('Epochs')
#       5 plt.ylabel('Accuracy')
#
# NameError: name 'history' is not defined

# %%
scores = model.evaluate(actual_value,ans,verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 86.42%

# %%
print('actual value')
print(' RH2M   PS  T2M_RANGE T2M_MAX T2M_MIN WS10M_RANGE')

print(pd.DataFrame(actual_value))
print('predicted value')
print(' PRECTOT RH2M PS T2M_RANGE T2M_MAX T2M_MIN T2M WS10M_RANGE')

print(pd.DataFrame(ans))
# Out:
# actual value
#  RH2M   PS  T2M_RANGE T2M_MAX T2M_MIN WS10M_RANGE
#        0      1      2      3     4     5
# 0    0.0  47.02  83.91  14.43  4.05  2.75
# 1    0.0  46.43  83.90  14.63  2.87  3.58
# 2    0.0  43.62  84.08  15.24  4.32  3.50
# 3    0.0  42.26  83.95  13.50  2.91  3.85
# 4    0.0  40.81  83.80  13.47  2.61  3.56
# ..   ...    ...    ...    ...   ...   ...
# 724  0.0  54.14  84.01  11.10  0.29  2.62
# 725  0.0  50.06  84.27  12.44 -2.01  2.69
# 726  0.0  44.74  84.33  13.56  3.12  2.42
# 727  0.0  44.56  84.39  13.74  3.24  2.63
# 728  0.0  40.99  84.51  13.63  4.76  2.74
#
# [729 rows x 6 columns]
# predicted value
#  PRECTOT RH2M PS T2M_RANGE T2M_MAX T2M_MIN T2M WS10M_RANGE
#             0          1          2          3         4         5
# 0   -0.848998  42.596260  84.135658  16.603422  5.291943  3.673686
# 1   -0.577767  46.604271  84.062454  14.800923  3.883410  3.571388
# 2   -0.668408  43.986977  84.035561  14.781254  3.211802  3.892683
# 3   -0.941887  43.209297  84.163864  15.732800  4.222053  3.754042
# 4   -0.829611  41.250553  84.061638  14.398915  2.454401  3.948342
# ..        ...        ...        ...        ...       ...       ...
# 724 -0.784883  48.845325  84.173958  12.327225  1.551542  3.228203
# 725 -0.620410  50.457413  84.117432  11.502496  0.722832  3.275125
# 726 -0.777541  45.333153  84.257149  11.751032  0.304094  3.199656
# 727 -1.128327  45.619370  84.330803  14.065031  3.133917  3.120215
# 728 -1.225022  45.401070  84.364006  14.274556  3.273494  3.149885
#
# [729 rows x 6 columns]

# %%
66
a=input('Enter the date of day whose weather you would like to predict ')
print('Enter the weather parameters of previous day')
a=[]
print('Precipitation , Relative humidity, Surface pressure , MAX temp ,MIN_temp ,Wind speed at 10M' )
#Precipitation , Relative humidity, Surface pressure , Temperature range, MAX temp ,MIN_temp ,Temperature ,Wind speed at 10M 
for i in range(0,6):
 a.append(float(input()))
a=np.array(a) 
a.shape=(1,6)
#a=pd.DataFrame(a)

#print(a)
print('The entered  weather parameters are :\n')
print('Precipitation=', a[0,0],'mm' ,'\n Relative humidity=',a[0,1],'%', '\n Surface pressure=',a[0,2],'kPa' , '\n MAX temp=',a[0,3],'C',  '\n MIN_temp=',a[0,4],'C' , '\n Wind speed at 10M=',a[0,5] ,'m/s\n\n\n')

a=scalar.transform(a)

ans1=model.predict(a)
ans2=scalar.inverse_transform(ans1)
print('The predicted weather parameters are :\n')
print('Precipitation=', ans2[0,0],'mm' ,'\n Relative humidity=',ans2[0,1],'%', '\n Surface pressure=',ans2[0,2],'kPa' , '\n MAX temp=',ans2[0,3],'C',  '\n MIN_temp=',ans2[0,4],'C' , '\n Wind speed at 10M=',ans2[0,5] ,'m/s')
#print(ans2)
# Out:
# Enter the date of day whose weather you would like to predict 2020/1/1
# Enter the weather parameters of previous day
# Precipitation , Relative humidity, Surface pressure , MAX temp ,MIN_temp ,Wind speed at 10M
# 0
# 53.62
# 84.67
# 11.67
# 5.12
# 1.1
# The entered  weather parameters are :
#
# Precipitation= 0.0 mm
#  Relative humidity= 53.62 %
#  Surface pressure= 84.67 kPa
#  MAX temp= 11.67 C
#  MIN_temp= 5.12 C
#  Wind speed at 10M= 1.1 m/s
#
#
#
# The predicted weather parameters are :
#
# Precipitation= -1.7850426 mm
#  Relative humidity= 55.700047 %
#  Surface pressure= 84.52854 kPa
#  MAX temp= 13.306257 C
#  MIN_temp= 3.8064487 C
#  Wind speed at 10M= 2.3527853 m/s
